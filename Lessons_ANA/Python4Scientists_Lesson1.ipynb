# %% [markdown]
# # Lesson 1 - Introduction
# Esta é nossa primeira aula.

# %% [markdown]
# ## Getting to know the Notebook

# %% [markdown]
# Two types of cells:
#
#
# *   Code cells
# *   Text cells
#
#
#
# 1.   Item 1
# 2.   Item 2

# %% [markdown]
# Hi hello!

# %% [markdown]
# Hi hello. (shift + enter = executes)

# %% [markdown]
# This is a **text** cell. It can be formatted with  **images**, **HTML**, **LaTeX**. <br>
# For example **LaTeX**:<br>
# $Y_t - Y_{t-1} = \rho Y_{t-1} - Y_{t-1} + \epsilon   $
#
# $\Delta Y_t = (\rho - 1) Y_{t-1} + \epsilon$
#
# **Image**: <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Titulo
# ##  sub-titulo
# ### sub-sub-titulos

# %%
# Header 1
## Section 1.1
### Sub-section 1.1.1
#### And we can continue

# %%
# comment
5
# Out:
# 5

# %%
6+2
# Out:
# 8

# %%
2 + 2
# Out:
# 4

# %%
chuva = 10

# %%
bacia = 'doce'

# %%
chuva
# Out:
# 10

# %%
bacia
# Out:
# 'doce'

# %%
5 + 2
# Out:
# 7

# %%
# Pay attention to the execution order!
5 / 2
# Out:
# 2.5

# %% [markdown]
# <b>Note</b> It has some differences to the standard implementation of Jupyter Notebook (ex. shortcuts)
#
# ---

# %% [markdown]
# ## Basic Types (part 1)

# %% [markdown]
# ### Numbers

# %%
# integers
265
# Out:
# 265

# %%
# Real (called float)
235.45
# Out:
# 235.45

# %%
# Binary (called Boolean)
True, False
# Out:
# (True, False)

# %%
# complex
2 + 4j
# Out:
# (2+4j)

# %%
# function(123123)
type(2 + 4j)
# Out:
# complex

# %%
type(2), type(2.)
# Out:
# (int, float)

# %%
3/2
# Out:
# 1.5

# %%
type(3/2)
# Out:
# float

# %%
3/2
# Out:
# 1.5

# %% [markdown]
# #### Operations
# All arithmetic operators:
# *   +, -, *, /
# *   %, **, //

# %%
13%5
# Out:
# 3

# %%
13//5
# Out:
# 2

# %%
13/5
# Out:
# 2.6

# %%
# % -> Modulus operator
print(13/5)
print(13%5)
# Out:
# 2.6
# 3

# %%
# // -> Floor division
13//2
# Out:
# 6

# %%
# ** -> expoent
3**3
# Out:
# 27

# %%
print(2)
type(5)
# Out:
# 2
# int

# %%
# operators precedence
print( 2*2**2 )
print( (2*(2+1))**2 )
# Out:
# 8
# 36

# %% [markdown]
# **Note:** Don't use square brackets [ ].or curly brackets to write expressions

# %% [markdown]
# #### Comparison Operators
# ==, !=, >, <, >=, <=

# %%
# the result is always a boolean
3 == 3
# Out:
# True

# %%
1>2
# Out:
# False

# %%
123 >= 122.99
# Out:
# True

# %%
chuva1 = 10
chuva2 = 20

# %%
chuva2 = chuva1

# %%
chuva2, chuva1
# Out:
# (10, 10)

# %%
chuva = 20

# %%
chuva2 == chuva1
# Out:
# True

# %% [markdown]
# #### Logical Operators
# Always compare booleans <br>
# and, or, not

# %%
not True
# Out:
# False

# %%
(2 < 5) and (3 < 4)
# Out:
# True

# %%
not 2 > 5 or 3 < 4
# Out:
# True

# %% [markdown]
# https://www.programiz.com/python-programming/precedence-associativity

# %%
# it doesn't matter the precedence
# True and True or False and not False

# %% [markdown]
# #### Bitwise operators
#
# * & - AND
# * | - OR
# * ^ - XOR
# * ~ - NOT
# * << Left shift
# * '>>' Right shift
#
# If you thought you could skip this class....<br>
#
# https://medium.com/analytics-vidhya/python-for-geosciences-raster-bit-masks-explained-step-by-step-8620ed27141e
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Strings

# %%
print("Priscilla")
"Hello World!"
# Out:
# Priscilla
# 'Hello World!'

# %%
"5 + 2"
# Out:
# '5 + 2'

# %%
7 + 2
# Out:
# 9

# %%
"Hello" + " world!"
# Out:
# 'Hello world!'

# %%
"Hello!" == "Hello!"
# Out:
# True

# %%
# check alphabetical order
"Jean" > "Klbin"
# Out:
# False

# %%
type(bacia)
# Out:
# str

# %%
3 == int("3")
# Out:
# True

# %%
float("5.568") + 2
# Out:
# 7.568

# %%
float type int print str

# %%
print(str(chuva) + " mm")
# Out:
# 20 mm

# %%
# Some operations are note defined
# "Hello" - "H"
"Hello" < str(3)
# Out:
# False

# %% [markdown]
# ### Variables

# %%
chuva
# Out:
# 20

# %%
'chuva3'
# Out:
# 'chuva3'

# %%
a = 23  
b = -7.89
type(a), type(b)
# Out:
# (int, float)

# %%
a + b
# Out:
# 15.11

# %%
s12345 = "Hello world!"
print(s12345)
type(s12345)
# Out:
# Hello world!
# str

# %%
a < b
# Out:
# False

# %% [markdown]
# ### Lists
# Up to now, everything could be done with a good calculator... now things will get better.<br>
#
# Ordered, accepts duplicates (diff from set) and can contain different data types.

# %%
a, b, chuva, bacia
# Out:
# (23, -7.89, 20, 'doce')

# %%
lst = [10, b, 'a', bacia]

# %%
print(lst)
# Out:
# [10, -7.89, 'a', 'doce']

# %%
len(lst)
# Out:
# 4

# %%
lst = [1, "Hello", 3.5, 4, ["innerList_item1", "innerList_item2"], 6]
lst
# Out:
# [1, 'Hello', 3.5, 4, ['innerList_item1', 'innerList_item2'], 6]

# %%
len(lst)
# Out:
# 6

# %% [markdown]
# ### Indexing/Slicing
# It's a way to refer to individual/subset of items within a list.<br>
# Python indexing is Zero-Based

# %%
# Examples of indexing
# Get the first item and the last item
lst[0], lst[-1]
# Out:
# (1, 6)

# %%
# este é o 4o elemento
lst[3]
# Out:
# 4

# %%
lst[0:3]
# Out:
# [1, 'Hello', 3.5]

# %%
lst1 = lst

# %%
lst[:3]
# Out:
# [1, 'Hello', 3.5]

# %%
lst
# Out:
# [1, 'Hello', 3.5, 4, ['innerList_item1', 'innerList_item2'], 6]

# %%
lst
# Out:
# [1, 'Hello', 3.5, 4, ['innerList_item1', 'innerList_item2'], 6]

# %%
for el in lst:
    if type(el) == list:
        print(el)
# Out:
# ['innerList_item1', 'innerList_item2']

# %%
type(lst) == list
# Out:
# True

# %%
type([123])
# Out:
# list

# %%
# Examples of slicing
# OBS: The slicing don't include the last item. So, 0:3 will return the 3 first 
# elements

# [1, 10) - > 1.....9

# Syntax is: list[first index:last_index (excludent)]
lst[0:3]
# Out:
# [1, 'Hello', 3.5]

# %%
lst[3:6]
# Out:
# [4, ['innerList_item1', 'innerList_item2'], 6]

# %%
list2 = lst[-2]

# %%
lst[-2][0]
# Out:
# 'innerList_item1'

# %%
# It can work with strings, as well
lst[-2][0][-5:]
# Out:
# 'item1'

# %%
lst[-2][0][:5]
# Out:
# 'inner'
